# %%
import pandas as pd
import numpy as np
from datetime import datetime

src_train = pd.read_csv('training_set.csv', delimiter=';')
# Save predictions
src_score_org = pd.read_csv('test_set.csv', delimiter=';')
src_score = pd.read_csv('test_set.csv', delimiter=';')

def runDataManipulation(df):
    # Data manipulation
    for col in ['fecha_reserva', 'check-in', 'check-out']:
      df[col] = df[col].apply(lambda d: datetime.strptime(d, '%Y-%m-%d'))  

def computeColumns(df):
# Computed columns
    df['release'] = df.apply(lambda r: (r['check-in'] - r['fecha_reserva']).days, axis=1)
    df['bookmonth'] = df['fecha_reserva'].apply(lambda d: d.month)
    df['checkinmonth'] = df['check-in'].apply(lambda d: d.month)

for df in [src_train, src_score]:  
    runDataManipulation(df)
    computeColumns(df)

msk = np.random.rand(len(src_train)) < 0.8
df_train = src_train[msk]
df_test = src_train[~msk]
print("Train %d test %d" % (len(df_train), len(df_test)))
df_train.head()
# Out:
# Train 21892 test 5476
#    index fecha_reserva          pais_cliente  importe_reserva  roomnigths  \
# 1      1    2017-06-01                España         0.008979           7
# 2      2    2017-06-01           Reino Unido         0.004807           2
# 3      3    2017-06-01                España         0.001905           2
# 4      4    2017-06-01                España         0.004168           4
# 5      5    2017-06-01  República Dominicana         0.012608           6
#
#     check-in  check-out  is_reserva_cancelada  total_habitaciones  \
# 1 2017-06-11 2017-06-18                     1                   1
# 2 2017-06-16 2017-06-18                     0                   1
# 3 2017-06-11 2017-06-13                     0                   1
# 4 2017-09-10 2017-09-14                     1                   1
# 5 2017-06-29 2017-07-02                     0                   2
#
#                                       hotel  \
# 1  d46b813cd813e2318a35509103b1f081db5f77a3
# 2  5e15fec283ff9ceb8449e558d8c5c81ac9fd2cfc
# 3  3c0e030d4ab643f402af566b86266cbaf6a610ef
# 4  d46b813cd813e2318a35509103b1f081db5f77a3
# 5  290d5f265e3662e4df4e4e4a90f1612cc68404f8
#
#                                 localizador  \
# 1  a5af59e5353d2aa9a1ad1af0efc2c705f51081af
# 2  810f16cec64559f3bd15cba281e750d0561324bd
# 3  63f9e567275d9d767c2772670b49d9a3c44a5be0
# 4  363a04550045efd2d4fea70117b80620081c3746
# 5  0d39566a4b888d10bb722891bbf3c6bd289066c4
#
#                              nombre_cliente  \
# 1  c2fc06233869c2c9485b3f8705483308c6fb34fa
# 2  314f1860d9eac211285d704c56d053ed60726dc2
# 3  a12ee97fd2b7c328c7f32bf6b525d822a04a8738
# 4  8d324b5a1b93bf146f15f617160e1bd0ebf35cd5
# 5  39a6d2497a61d62fb0d3bfca033c22cf69b40b88
#
#                            telefono_cliente  \
# 1  aa0b0c3c980ffd82b0065d75e94ec2c8393ef1d4
# 2  b7b46949047ab5bc72b6f653bcbb4cbe001e940f
# 3  a0460d93425231616ed74397a2cb16fda09350a4
# 4  f8f1eefccc849c8fae2865ce599aeec89886ab60
# 5  f9ee45fc184944a910332c5177657418a75a6eae
#
#                               email_cliente  release  bookmonth  checkinmonth
# 1  a0ce353f75bd324baae267a698304c75df508557       10          6             6
# 2  4d2eaf0b2bdee0e348b9a735d6bf8cf27416b0ff       15          6             6
# 3  a0ce353f75bd324baae267a698304c75df508557       10          6             6
# 4  19a229a6aeb9d7e3d50df5428df48321ae5de6f8      101          6             9
# 5  657c22b1e3b43728df4f4a8e670e3971fad2105d       28          6             6

# %%
from auto_ml import Predictor

# Tell auto_ml which column is 'output'
# Also note columns that aren't purely numerical
# Examples include ['nlp', 'date', 'categorical', 'ignore']
column_descriptions = {
    'index':'ignore',
    'localizador': 'ignore',
    'nombre_cliente': 'ignore',
    'telefono_cliente': 'ignore',
    'email_cliente': 'ignore',
    'is_reserva_cancelada': 'output',
    'pais_cliente': 'categorical',
    'hotel': 'categorical',
    'localizador': 'categorical',
    'nombre_cliente': 'categorical',
    'telefono_cliente': 'categorical',
    'email_cliente': 'categorical',
    'fecha_reserva': 'date',
    'check-in': 'date',
    'check-out': 'date'
}

# Can pass in type_of_estimator='regressor' as well
ml_predictor = Predictor(type_of_estimator='classifier', column_descriptions=column_descriptions)

# Wait for the machine to learn all the complex and beautiful patterns in your data...
ml_predictor.train(df_train, ml_for_analytics=True)

# Score the model on test data
# test_score = ml_predictor.score(df_test, df_test.MEDV)

# .predict and .predict_proba take in either:
# A pandas DataFrame
# A list of dictionaries
# A single dictionary (optimized for speed in production evironments)
predictions = ml_predictor.predict(df_test)
# Out:
# Welcome to auto_ml! We're about to go through and make sense of your data using machine learning, and give you a production-ready pipeline to get predictions with.
#
# If you have any issues, or new feature ideas, let us know at https://github.com/ClimbsRocks/auto_ml
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'presort': False, 'learning_rate': 0.1, 'warm_start': True}
# Running basic data cleaning
# Performing feature scaling
# Fitting DataFrameVectorizer
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'presort': False, 'learning_rate': 0.1, 'warm_start': True}
#
#
# ********************************************************************************************
# About to fit the pipeline for the model GradientBoostingClassifier to predict is_reserva_cancelada
# Started at:
# 2017-11-04 13:02:15
# [1] random_holdout_set_from_training_data's score is: -0.214
# [2] random_holdout_set_from_training_data's score is: -0.211
# [3] random_holdout_set_from_training_data's score is: -0.21
# [4] random_holdout_set_from_training_data's score is: -0.208
# [5] random_holdout_set_from_training_data's score is: -0.207
# [6] random_holdout_set_from_training_data's score is: -0.205
# [7] random_holdout_set_from_training_data's score is: -0.204
# [8] random_holdout_set_from_training_data's score is: -0.204
# [9] random_holdout_set_from_training_data's score is: -0.203
# [10] random_holdout_set_from_training_data's score is: -0.202
# [11] random_holdout_set_from_training_data's score is: -0.201
# [12] random_holdout_set_from_training_data's score is: -0.201
# [13] random_holdout_set_from_training_data's score is: -0.2
# [14] random_holdout_set_from_training_data's score is: -0.2
# [15] random_holdout_set_from_training_data's score is: -0.199
# [16] random_holdout_set_from_training_data's score is: -0.199
# [17] random_holdout_set_from_training_data's score is: -0.199
# [18] random_holdout_set_from_training_data's score is: -0.198
# [19] random_holdout_set_from_training_data's score is: -0.198
# [20] random_holdout_set_from_training_data's score is: -0.198
# [21] random_holdout_set_from_training_data's score is: -0.197
# [22] random_holdout_set_from_training_data's score is: -0.197
# [23] random_holdout_set_from_training_data's score is: -0.197
# [24] random_holdout_set_from_training_data's score is: -0.197
# [25] random_holdout_set_from_training_data's score is: -0.196
# [26] random_holdout_set_from_training_data's score is: -0.196
# [27] random_holdout_set_from_training_data's score is: -0.196
# [28] random_holdout_set_from_training_data's score is: -0.196
# [29] random_holdout_set_from_training_data's score is: -0.196
# [30] random_holdout_set_from_training_data's score is: -0.196
# [31] random_holdout_set_from_training_data's score is: -0.195
# [32] random_holdout_set_from_training_data's score is: -0.195
# [33] random_holdout_set_from_training_data's score is: -0.195
# [34] random_holdout_set_from_training_data's score is: -0.195
# [35] random_holdout_set_from_training_data's score is: -0.195
# [36] random_holdout_set_from_training_data's score is: -0.195
# [37] random_holdout_set_from_training_data's score is: -0.195
# [38] random_holdout_set_from_training_data's score is: -0.194
# [39] random_holdout_set_from_training_data's score is: -0.194
# [40] random_holdout_set_from_training_data's score is: -0.194
# [41] random_holdout_set_from_training_data's score is: -0.194
# [42] random_holdout_set_from_training_data's score is: -0.194
# [43] random_holdout_set_from_training_data's score is: -0.194
# [44] random_holdout_set_from_training_data's score is: -0.194
# [45] random_holdout_set_from_training_data's score is: -0.194
# [46] random_holdout_set_from_training_data's score is: -0.194
# [47] random_holdout_set_from_training_data's score is: -0.194
# [48] random_holdout_set_from_training_data's score is: -0.194
# [49] random_holdout_set_from_training_data's score is: -0.194
# [50] random_holdout_set_from_training_data's score is: -0.194
# [52] random_holdout_set_from_training_data's score is: -0.194
# [54] random_holdout_set_from_training_data's score is: -0.194
# [56] random_holdout_set_from_training_data's score is: -0.193

# %%
# Where new_data is a single dictionary, or a DataFrame
predictions = ml_predictor.predict(df_test)
df_test['prediction'] = predictions 
df_test['match'] = df_test['prediction'] == df_test['is_reserva_cancelada'] 
classes = [[i,k] for i,k in enumerate(df_test['is_reserva_cancelada'])]
validation = list(map(lambda p: [p[1],predictions[p[0]],p[1] == predictions[p[0]]], classes))
print(validation[0:5])
total = len(validation)
ok = len(list(filter(lambda k: k[2], validation)))
perc = 100 / total * ok
print("Validation %d of %d - %f%%" % (ok, total, perc))
df_test.head()
# Out:
# [[0, 0, True], [1, 0, False], [0, 0, True], [0, 0, True], [0, 1, False]]
# Validation 4045 of 5519 - 73.292263%
#     index fecha_reserva pais_cliente  importe_reserva  roomnigths   check-in  \
# 18     20    2017-06-01       España         0.000558           1 2017-10-28
# 19     21    2017-06-01       España         0.005737           9 2017-06-28
# 22     24    2017-06-01   Afganistan         0.001172           1 2017-07-01
# 24     27    2017-06-01       España         0.000989           2 2017-06-05
# 36     39    2017-06-01       España         0.002331           2 2017-10-17
#
#     check-out  is_reserva_cancelada  total_habitaciones  \
# 18 2017-10-29                     0                   1
# 19 2017-07-07                     1                   1
# 22 2017-07-02                     0                   1
# 24 2017-06-07                     0                   1
# 36 2017-10-19                     0                   1
#
#                                        hotel  \
# 18  c583069e358d4f83cbded00b32215ecc91a969ea
# 19  c583069e358d4f83cbded00b32215ecc91a969ea
# 22  8a323d67734b2037d099de6624bfe0494ff7130b
# 24  d3f6e27a92966b8aa81c3a7adf89683d659a9605
# 36  0cb187811a7004273fe5af314f1762a54149e953
#
#                                  localizador  \
# 18  d8da8b082444b3b3efb277a5a7ec6d82118a30b4
# 19  292feb262360fd56fdaac3f52bb381e1bec0ef37
# 22  84c49ed9e94a799c79618edc7fb4571ac48e337f
# 24  2a9913899a00811ad49b31a4a0fbb103d32ea3c8
# 36  c606643ace06aa64a826879b304b872136f02720
#
#                               nombre_cliente  \
# 18  c823dd31043fb3bcda19c8f092a9dc48eab75f9c
# 19  ea14fe3b54fbe37c4401d0f26a7c8adf87e7e245
# 22  2a3ec161d79ce397368023d64a9c44210625245f
# 24  71994e5bd1f5b2fdcb71c9b9ebdfba64feca8939
# 36  2a2ff195791d2ef3e327cb4fc37d1b003aa403fd
#
#                             telefono_cliente  \
# 18  4e9a5d7cb2ad6e25ab47647cc7007e82fea7886c
# 19  2800ebfaf82b003aba860bc5df71ee0e8e89948d
# 22  67f9e5df2b30969b83428c18d8e457bf4973f6cd
# 24  216f8bdcc93ca4b9f9e49ab88680e8ef8c8a989f
# 36  60a4301982ca01f7335dcb1797a470184100deba
#
#                                email_cliente  release  prediction  match
# 18  a0ce353f75bd324baae267a698304c75df508557      149           0   True
# 19  2800ebfaf82b003aba860bc5df71ee0e8e89948d       27           0  False
# 22  5d7876f0ed540e172bbd80df1ae3df883f3c81b2       30           0   True
# 24  2ae1efa49f4873232599618ef89b0aa1a4fb74b8        4           0   True
# 36  2a706541c658c6292a29a90f5718a63bc670d2a2      138           1  False

# %%
# Where new_data is a single dictionary, or a DataFrame
predictions = ml_predictor.predict(src_score)
src_score_org['probabilidad'] = predictions
# print(len(list(filter(lambda x: x != 0, predictions))))
src_score_org.head()
import time
millis = int(round(time.time() * 1000))
fname = 'gustavobrianA%d_test_%d.csv'  %(int(perc), millis)
src_score_org.to_csv(fname, columns = ['index','probabilidad'], index=False)
